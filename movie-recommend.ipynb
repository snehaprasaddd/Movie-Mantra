# %%
import numpy as np
import pandas as pd

# %%
movies =pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                              genres original_language  \
# 0     Action-Science Fiction-Horror                en
# 1           Horror-Mystery-Thriller                en
# 2  Action-Adventure-Science Fiction                en
# 3  Action-Adventure-Science Fiction                en
# 4                      Drama-Action                en
#
#                                             overview  popularity  \
# 0  An exploratory dive into the deepest depths of...    8763.998
# 1  Father Gabriele Amorth Chief Exorcist of the V...    5953.227
# 2  When a new threat capable of destroying the en...    5409.104
# 3  Super-Hero partners Scott Lang and Hope van Dy...    4425.387
# 4  After dominating the boxing world Adonis Creed...    3994.342
#
#                                 production_companies release_date  \
# 0  Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 1  Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2  Skydance-Paramount-di Bonaventura Pictures-Bay...   2023-06-06
# 3             Marvel Studios-Kevin Feige Productions   2023-02-15
# 4  Metro-Goldwyn-Mayer-Proximity Media-Balboa Pro...   2023-03-01
#
#         budget      revenue  runtime    status  \
# 0  129000000.0  352056482.0    116.0  Released
# 1   18000000.0   65675816.0    103.0  Released
# 2  200000000.0  407045464.0    127.0  Released
# 3  200000000.0  475766228.0    125.0  Released
# 4   75000000.0  269000000.0    116.0  Released
#
#                                              tagline  vote_average  \
# 0                                  Back for seconds.         7.079
# 1  Inspired by the actual files of Father Gabriel...         7.433
# 2                                     Unite or fall.         7.340
# 3            Witness the beginning of a new dynasty.         6.507
# 4                      You can't run from your past.         7.262
#
#    vote_count                                            credits  \
# 0      1365.0  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 1       545.0  Russell Crowe-Daniel Zovatto-Alex Essoe-Franco...
# 2      1007.0  Anthony Ramos-Dominique Fishback-Luna Lauren V...
# 3      2811.0  Paul Rudd-Evangeline Lilly-Jonathan Majors-Kat...
# 4      1129.0  Michael B. Jordan-Tessa Thompson-Jonathan Majo...
#
#                                             keywords  \
# 0                based on novel or book-sequel-kaiju
# 1  spain-rome italy-vatican-pope-pig-possession-c...
# 2  peru-alien-end of the world-based on cartoon-b...
# 3  hero-ant-sequel-superhero-based on comic-famil...
# 4  philadelphia pennsylvania-husband wife relatio...
#
#                         poster_path                     backdrop_path  \
# 0  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /qlxy8yo5bcgUw2KAmmojUKp4rHd.jpg
# 1  /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg  /hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg
# 2  /gPbM0MK8CP8A174rmUwGsADNYKD.jpg  /woJbg7ZqidhpvqFGGMRhWQNoxwa.jpg
# 3  /qnqGbB22YJ7dSs4o6M7exTpNxPz.jpg  /m8JTwHFwX7I7JY5fPe4SjqejWag.jpg
# 4  /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg
#
#                                      recommendations
# 0  1006462-298618-569094-1061181-346698-1076487-6...
# 1  713704-296271-502356-1076605-1084225-1008005-9...
# 2  496450-569094-298618-385687-877100-598331-4628...
# 3  823999-676841-868759-734048-267805-965839-1033...
# 4  965839-267805-943822-842942-1035806-823999-107...

# %%
#genre
#id
#keywords
#title
#overview
#runtime
movies=movies[['id','title','genres','keywords','overview','runtime']]

# %%
movies.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                              genres  \
# 0     Action-Science Fiction-Horror
# 1           Horror-Mystery-Thriller
# 2  Action-Adventure-Science Fiction
# 3  Action-Adventure-Science Fiction
# 4                      Drama-Action
#
#                                             keywords  \
# 0                based on novel or book-sequel-kaiju
# 1  spain-rome italy-vatican-pope-pig-possession-c...
# 2  peru-alien-end of the world-based on cartoon-b...
# 3  hero-ant-sequel-superhero-based on comic-famil...
# 4  philadelphia pennsylvania-husband wife relatio...
#
#                                             overview  runtime
# 0  An exploratory dive into the deepest depths of...    116.0
# 1  Father Gabriele Amorth Chief Exorcist of the V...    103.0
# 2  When a new threat capable of destroying the en...    127.0
# 3  Super-Hero partners Scott Lang and Hope van Dy...    125.0
# 4  After dominating the boxing world Adonis Creed...    116.0

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# genres      0
# keywords    0
# overview    0
# runtime     0
# tags        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 movies.duplicated().sum()
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\frame.py:6662, in DataFrame.duplicated(self, subset, keep)
#    6660 else:
#    6661     vals = (col.values for name, col in self.items() if name in subset)
# -> 6662     labels, shape = map(list, zip(*map(f, vals)))
#    6664     ids = get_group_index(
#    6665         labels,
#    6666         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6670         xnull=False,
#    6671     )
#    6672     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\frame.py:6630, in DataFrame.duplicated.<locals>.f(vals)
#    6629 def f(vals) -> tuple[np.ndarray, int]:
# -> 6630     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6631     return labels.astype("i8", copy=False), len(shape)
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas\_libs\hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
movies.drop_duplicates(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 movies.drop_duplicates(inplace=True)
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\frame.py:6522, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6519 inplace = validate_bool_kwarg(inplace, "inplace")
#    6520 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6522 result = self[-self.duplicated(subset, keep=keep)]
#    6523 if ignore_index:
#    6524     result.index = default_index(len(result))
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\frame.py:6662, in DataFrame.duplicated(self, subset, keep)
#    6660 else:
#    6661     vals = (col.values for name, col in self.items() if name in subset)
# -> 6662     labels, shape = map(list, zip(*map(f, vals)))
#    6664     ids = get_group_index(
#    6665         labels,
#    6666         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6670         xnull=False,
#    6671     )
#    6672     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\frame.py:6630, in DataFrame.duplicated.<locals>.f(vals)
#    6629 def f(vals) -> tuple[np.ndarray, int]:
# -> 6630     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6631     return labels.astype("i8", copy=False), len(shape)
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File ~\Desktop\Movie-Mantra\env\Lib\site-packages\pandas\core\algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas\_libs\hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
movies.iloc[10].genres
# Out:
# 'Action-Adventure-Animation-Science Fiction'

# %%
def convert(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                              genres  \
# 0     Action-Science Fiction-Horror
# 1           Horror-Mystery-Thriller
# 2  Action-Adventure-Science Fiction
# 3  Action-Adventure-Science Fiction
# 4                      Drama-Action
#
#                                             keywords  \
# 0                based on novel or book-sequel-kaiju
# 1  spain-rome italy-vatican-pope-pig-possession-c...
# 2  peru-alien-end of the world-based on cartoon-b...
# 3  hero-ant-sequel-superhero-based on comic-famil...
# 4  philadelphia pennsylvania-husband wife relatio...
#
#                                             overview  runtime
# 0  An exploratory dive into the deepest depths of...    116.0
# 1  Father Gabriele Amorth Chief Exorcist of the V...    103.0
# 2  When a new threat capable of destroying the en...    127.0
# 3  Super-Hero partners Scott Lang and Hope van Dy...    125.0
# 4  After dominating the boxing world Adonis Creed...    116.0

# %%
movies.overview[0]
# Out:
# 'An exploratory dive into the deepest depths of the ocean of a daring research team spirals into chaos when a malevolent mining operation threatens their mission and forces them into a high-stakes battle for survival.'

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())

# %%
movies.keywords[0]
# Out:
# 'based on novel or book-sequel-kaiju'

# %%
movies['keywords']=movies['keywords'].apply(lambda x:x.split())

# %%
movies['genres']=movies['genres'].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                                 genres  \
# 0     [Action-Science, Fiction-Horror]
# 1            [Horror-Mystery-Thriller]
# 2  [Action-Adventure-Science, Fiction]
# 3  [Action-Adventure-Science, Fiction]
# 4                       [Drama-Action]
#
#                                             keywords  \
# 0          [based, on, novel, or, book-sequel-kaiju]
# 1  [spain-rome, italy-vatican-pope-pig-possession...
# 2  [peru-alien-end, of, the, world-based, on, car...
# 3  [hero-ant-sequel-superhero-based, on, comic-fa...
# 4  [philadelphia, pennsylvania-husband, wife, rel...
#
#                                             overview  runtime
# 0  [An, exploratory, dive, into, the, deepest, de...    116.0
# 1  [Father, Gabriele, Amorth, Chief, Exorcist, of...    103.0
# 2  [When, a, new, threat, capable, of, destroying...    127.0
# 3  [Super-Hero, partners, Scott, Lang, and, Hope,...    125.0
# 4  [After, dominating, the, boxing, world, Adonis...    116.0

# %%
movies['tags']=movies['overview']+movies['genres']+movies['keywords']

# %%
movies.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                                 genres  \
# 0     [Action-Science, Fiction-Horror]
# 1            [Horror-Mystery-Thriller]
# 2  [Action-Adventure-Science, Fiction]
# 3  [Action-Adventure-Science, Fiction]
# 4                       [Drama-Action]
#
#                                             keywords  \
# 0          [based, on, novel, or, book-sequel-kaiju]
# 1  [spain-rome, italy-vatican-pope-pig-possession...
# 2  [peru-alien-end, of, the, world-based, on, car...
# 3  [hero-ant-sequel-superhero-based, on, comic-fa...
# 4  [philadelphia, pennsylvania-husband, wife, rel...
#
#                                             overview  runtime  \
# 0  [An, exploratory, dive, into, the, deepest, de...    116.0
# 1  [Father, Gabriele, Amorth, Chief, Exorcist, of...    103.0
# 2  [When, a, new, threat, capable, of, destroying...    127.0
# 3  [Super-Hero, partners, Scott, Lang, and, Hope,...    125.0
# 4  [After, dominating, the, boxing, world, Adonis...    116.0
#
#                                                 tags
# 0  [An, exploratory, dive, into, the, deepest, de...
# 1  [Father, Gabriele, Amorth, Chief, Exorcist, of...
# 2  [When, a, new, threat, capable, of, destroying...
# 3  [Super-Hero, partners, Scott, Lang, and, Hope,...
# 4  [After, dominating, the, boxing, world, Adonis...

# %%
new_df=movies[['id','title','tags']]

# %%
new_df['tags']=new_df['tags'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_7108\684433085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x: " ".join(x))

# %%
new_df.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                                                 tags
# 0  An exploratory dive into the deepest depths of...
# 1  Father Gabriele Amorth Chief Exorcist of the V...
# 2  When a new threat capable of destroying the en...
# 3  Super-Hero partners Scott Lang and Hope van Dy...
# 4  After dominating the boxing world Adonis Creed...

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_7108\4224080999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                                                 tags
# 0  an exploratory dive into the deepest depths of...
# 1  father gabriele amorth chief exorcist of the v...
# 2  when a new threat capable of destroying the en...
# 3  super-hero partners scott lang and hope van dy...
# 4  after dominating the boxing world adonis creed...
